# %%
from pycaret.classification import *

# %%
from pycaret.datasets import get_data

# %%
data = get_data("diabetes")
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
data.shape
# Out:
# (768, 9)

# %%
data.columns
# Out:
# Index(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)', 'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)', 'Class variable'],
#       dtype='object')

# %%
data.size
# Out:
# 6912

# %%
data.head() #check first 5 rows of data
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age (years)  Class variable
# 0           50               1
# 1           31               0
# 2           32               1
# 3           21               0
# 4           33               1

# %%
data.describe()
# Out:
#        Number of times pregnant  \
# count                768.000000
# mean                   3.845052
# std                    3.369578
# min                    0.000000
# 25%                    1.000000
# 50%                    3.000000
# 75%                    6.000000
# max                   17.000000
#
#        Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# count                                         768.000000
# mean                                          120.894531
# std                                            31.972618
# min                                             0.000000
# 25%                                            99.000000
# 50%                                           117.000000
# 75%                                           140.250000
# max                                           199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# count                        768.000000                        768.000000
# mean                          69.105469                         20.536458
# std                           19.355807                         15.952218
# min                            0.000000                          0.000000
# 25%                           62.000000                          0.000000
# 50%                           72.000000                         23.000000
# 75%                           80.000000                         32.000000
# max                          122.000000                         99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function  Age (years)  Class variable
# count                  768.000000   768.000000      768.000000
# mean                     0.471876    33.240885        0.348958
# std                      0.331329    11.760232        0.476951
# min                      0.078000    21.000000        0.000000
# 25%                      0.243750    24.000000        0.000000
# 50%                      0.372500    29.000000        0.000000
# 75%                      0.626250    41.000000        1.000000
# max                      2.420000    81.000000        1.000000

# %%
#setup
# target variable name is Class variable in the dataset
clf = setup(data = data, target = "Class variable")
# Out:
# <style type="text/css">
# #T_3f63b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_3f63b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f63b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_3f63b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f63b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f63b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_3f63b_row0_col1" class="data row0 col1" >8647</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3f63b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_3f63b_row1_col1" class="data row1 col1" >Class variable</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3f63b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_3f63b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3f63b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_3f63b_row3_col1" class="data row3 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3f63b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_3f63b_row4_col1" class="data row4 col1" >(768, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3f63b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_3f63b_row5_col1" class="data row5 col1" >(537, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3f63b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_3f63b_row6_col1" class="data row6 col1" >(231, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3f63b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_3f63b_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3f63b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_3f63b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3f63b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_3f63b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3f63b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_3f63b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3f63b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_3f63b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3f63b_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_3f63b_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3f63b_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_3f63b_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3f63b_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_3f63b_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3f63b_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_3f63b_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3f63b_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_3f63b_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3f63b_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_3f63b_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_3f63b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3f63b_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_3f63b_row18_col1" class="data row18 col1" >ecaf</td>
#     </tr>
#   </tbody>
# </table>

# %%
boston = get_data("boston")
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
from pycaret.regression import *

# %%
reql = setup( data = boston, target = "medv")
# Out:
# <style type="text/css">
# #T_89ee6_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_89ee6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89ee6_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_89ee6_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89ee6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89ee6_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_89ee6_row0_col1" class="data row0 col1" >5883</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89ee6_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_89ee6_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89ee6_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_89ee6_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89ee6_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_89ee6_row3_col1" class="data row3 col1" >(506, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_89ee6_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_89ee6_row4_col1" class="data row4 col1" >(506, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_89ee6_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_89ee6_row5_col1" class="data row5 col1" >(354, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_89ee6_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_89ee6_row6_col1" class="data row6 col1" >(152, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_89ee6_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_89ee6_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_89ee6_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_89ee6_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_89ee6_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_89ee6_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_89ee6_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_89ee6_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_89ee6_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_89ee6_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_89ee6_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_89ee6_row12_col1" class="data row12 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_89ee6_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_89ee6_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_89ee6_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_89ee6_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_89ee6_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_89ee6_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_89ee6_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_89ee6_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_89ee6_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_89ee6_row17_col1" class="data row17 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_89ee6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_89ee6_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_89ee6_row18_col1" class="data row18 col1" >c3a3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Linear Regression: used for continuous variables

# %%
dataset = get_data("diamond")
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
#price is the target variable, the rest are independent variables.

# %%
dataset.describe()
# Out:
#        Carat Weight          Price
# count   6000.000000    6000.000000
# mean       1.334520   11791.579333
# std        0.475696   10184.350051
# min        0.750000    2184.000000
# 25%        1.000000    5150.500000
# 50%        1.130000    7857.000000
# 75%        1.590000   15036.500000
# max        2.910000  101561.000000

# %%
data_train = dataset.sample(frac=0.9, random_state=786)
# Select a random sample of 90% of the data for training and set random state to any number

# %%
data_train.describe()
# Out:
#        Carat Weight          Price
# count   5400.000000    5400.000000
# mean       1.329983   11735.976667
# std        0.473852   10187.484916
# min        0.750000    2184.000000
# 25%        1.000000    5115.750000
# 50%        1.130000    7784.500000
# 75%        1.580000   14874.750000
# max        2.910000  101561.000000

# %%
data_train.head()
# Out:
#       Carat Weight        Cut Color Clarity Polish Symmetry Report  Price
# 5333          1.50       Good     E     VS2     VG        G    GIA  12702
# 3749          1.08      Ideal     D     VS2     EX       EX    GIA   8481
# 2376          2.25       Good     I     VS2      G       VG    GIA  18623
# 3756          2.27  Very Good     G     VS2     VG       VG    GIA  27252
# 4248          1.20      Ideal     F     VS1     EX       EX    GIA   9641

# %%
data_test = dataset.drop(data_train.index)
#drop all samples taken for training

# %%
data_test.shape
# Out:
# (600, 8)

# %%
data_train.reset_index(drop = True, inplace = True) #training dataset in proper order

# %%
data_train.head()
# Out:
#    Carat Weight        Cut Color Clarity Polish Symmetry Report  Price
# 0          1.50       Good     E     VS2     VG        G    GIA  12702
# 1          1.08      Ideal     D     VS2     EX       EX    GIA   8481
# 2          2.25       Good     I     VS2      G       VG    GIA  18623
# 3          2.27  Very Good     G     VS2     VG       VG    GIA  27252
# 4          1.20      Ideal     F     VS1     EX       EX    GIA   9641

# %%
data_test.reset_index(drop = True, inplace = True) #testing dataset in proper order

# %%
data_test.head()
# Out:
#    Carat Weight        Cut Color Clarity Polish Symmetry Report  Price
# 0          1.53      Ideal     E     SI1     ID       ID   AGSL  12791
# 1          1.50       Fair     F     SI1     VG       VG    GIA  10450
# 2          1.01       Good     E     SI1      G        G    GIA   5161
# 3          2.51  Very Good     G     VS2     VG       VG    GIA  34361
# 4          1.01       Good     I     SI1     VG       VG    GIA   4238

# %%
from pycaret.regression import *

# %%
reg = setup(data= data_train, target = "Price", session_id = 123)
# Out:
# <style type="text/css">
# #T_5b94e_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5b94e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5b94e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5b94e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5b94e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5b94e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5b94e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5b94e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5b94e_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5b94e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5b94e_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5b94e_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5b94e_row3_col1" class="data row3 col1" >(5400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5b94e_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5b94e_row4_col1" class="data row4 col1" >(5400, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5b94e_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5b94e_row5_col1" class="data row5 col1" >(3779, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5b94e_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5b94e_row6_col1" class="data row6 col1" >(1621, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5b94e_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_5b94e_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5b94e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_5b94e_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5b94e_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_5b94e_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5b94e_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_5b94e_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5b94e_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_5b94e_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5b94e_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_5b94e_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5b94e_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_5b94e_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5b94e_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_5b94e_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5b94e_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_5b94e_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5b94e_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_5b94e_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5b94e_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_5b94e_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5b94e_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_5b94e_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5b94e_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_5b94e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5b94e_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_5b94e_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5b94e_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_5b94e_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5b94e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5b94e_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_5b94e_row22_col1" class="data row22 col1" >3ec1</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(exclude = ["ransac"])
# Out:
# <style type="text/css">
# #T_5beae th {
#   text-align: left;
# }
# #T_5beae_row0_col0, #T_5beae_row0_col1, #T_5beae_row0_col5, #T_5beae_row0_col6, #T_5beae_row1_col0, #T_5beae_row1_col1, #T_5beae_row1_col2, #T_5beae_row1_col3, #T_5beae_row1_col4, #T_5beae_row1_col5, #T_5beae_row1_col6, #T_5beae_row2_col0, #T_5beae_row2_col2, #T_5beae_row2_col3, #T_5beae_row2_col4, #T_5beae_row3_col0, #T_5beae_row3_col1, #T_5beae_row3_col2, #T_5beae_row3_col3, #T_5beae_row3_col4, #T_5beae_row3_col5, #T_5beae_row3_col6, #T_5beae_row4_col0, #T_5beae_row4_col1, #T_5beae_row4_col2, #T_5beae_row4_col3, #T_5beae_row4_col4, #T_5beae_row4_col5, #T_5beae_row4_col6, #T_5beae_row5_col0, #T_5beae_row5_col1, #T_5beae_row5_col2, #T_5beae_row5_col3, #T_5beae_row5_col4, #T_5beae_row5_col5, #T_5beae_row5_col6, #T_5beae_row6_col0, #T_5beae_row6_col1, #T_5beae_row6_col2, #T_5beae_row6_col3, #T_5beae_row6_col4, #T_5beae_row6_col5, #T_5beae_row6_col6, #T_5beae_row7_col0, #T_5beae_row7_col1, #T_5beae_row7_col2, #T_5beae_row7_col3, #T_5beae_row7_col4, #T_5beae_row7_col5, #T_5beae_row7_col6, #T_5beae_row8_col0, #T_5beae_row8_col1, #T_5beae_row8_col2, #T_5beae_row8_col3, #T_5beae_row8_col4, #T_5beae_row8_col5, #T_5beae_row8_col6, #T_5beae_row9_col0, #T_5beae_row9_col1, #T_5beae_row9_col2, #T_5beae_row9_col3, #T_5beae_row9_col4, #T_5beae_row9_col5, #T_5beae_row9_col6, #T_5beae_row10_col0, #T_5beae_row10_col1, #T_5beae_row10_col2, #T_5beae_row10_col3, #T_5beae_row10_col4, #T_5beae_row10_col5, #T_5beae_row10_col6, #T_5beae_row11_col0, #T_5beae_row11_col1, #T_5beae_row11_col2, #T_5beae_row11_col3, #T_5beae_row11_col4, #T_5beae_row11_col5, #T_5beae_row11_col6, #T_5beae_row12_col0, #T_5beae_row12_col1, #T_5beae_row12_col2, #T_5beae_row12_col3, #T_5beae_row12_col4, #T_5beae_row12_col5, #T_5beae_row12_col6, #T_5beae_row13_col0, #T_5beae_row13_col1, #T_5beae_row13_col2, #T_5beae_row13_col3, #T_5beae_row13_col4, #T_5beae_row13_col5, #T_5beae_row13_col6, #T_5beae_row14_col0, #T_5beae_row14_col1, #T_5beae_row14_col2, #T_5beae_row14_col3, #T_5beae_row14_col4, #T_5beae_row14_col5, #T_5beae_row14_col6, #T_5beae_row15_col0, #T_5beae_row15_col1, #T_5beae_row15_col2, #T_5beae_row15_col3, #T_5beae_row15_col4, #T_5beae_row15_col5, #T_5beae_row15_col6, #T_5beae_row16_col0, #T_5beae_row16_col1, #T_5beae_row16_col2, #T_5beae_row16_col3, #T_5beae_row16_col4, #T_5beae_row16_col5, #T_5beae_row16_col6, #T_5beae_row17_col0, #T_5beae_row17_col1, #T_5beae_row17_col2, #T_5beae_row17_col3, #T_5beae_row17_col4, #T_5beae_row17_col5, #T_5beae_row17_col6 {
#   text-align: left;
# }
# #T_5beae_row0_col2, #T_5beae_row0_col3, #T_5beae_row0_col4, #T_5beae_row2_col1, #T_5beae_row2_col5, #T_5beae_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_5beae_row0_col7, #T_5beae_row1_col7, #T_5beae_row2_col7, #T_5beae_row3_col7, #T_5beae_row4_col7, #T_5beae_row5_col7, #T_5beae_row6_col7, #T_5beae_row7_col7, #T_5beae_row8_col7, #T_5beae_row9_col7, #T_5beae_row10_col7, #T_5beae_row11_col7, #T_5beae_row12_col7, #T_5beae_row13_col7, #T_5beae_row14_col7, #T_5beae_row15_col7, #T_5beae_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_5beae_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_5beae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5beae_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5beae_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_5beae_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_5beae_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_5beae_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_5beae_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_5beae_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_5beae_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5beae_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_5beae_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_5beae_row0_col1" class="data row0 col1" >758.7793</td>
#       <td id="T_5beae_row0_col2" class="data row0 col2" >2661557.6112</td>
#       <td id="T_5beae_row0_col3" class="data row0 col3" >1584.1538</td>
#       <td id="T_5beae_row0_col4" class="data row0 col4" >0.9743</td>
#       <td id="T_5beae_row0_col5" class="data row0 col5" >0.0820</td>
#       <td id="T_5beae_row0_col6" class="data row0 col6" >0.0608</td>
#       <td id="T_5beae_row0_col7" class="data row0 col7" >0.5930</td>
#     </tr>
#     <tr>
#       <th id="T_5beae_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_5beae_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_5beae_row1_col1" class="data row1 col1" >760.1499</td>
#       <td id="T_5beae_row1_col2" class="data row1 col2" >2944058.4839</td>
#       <td id="T_5beae_row1_col3" class="data row1 col3" >1663.3278</td>
#       <td id="T_5beae_row1_col4" class="data row1 col4" >0.9714</td>
#       <td id="T_5beae_row1_col5" class="data row1 col5" >0.0815</td>
#       <td id="T_5beae_row1_col6" class="data row1 col6" >0.0596</td>
#       <td id="T_5beae_row1_col7" class="data row1 col7" >0.5280</td>
#     </tr>
#     <tr>
#       <th id="T_5beae_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_5beae_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5beae_row2_col1" class="data row2 col1" >752.6246</td>
#       <td id="T_5beae_row2_col2" class="data row2 col2" >3056225.3710</td>
#       <td id="T_5beae_row2_col3" class="data row2 col3" >1687.9572</td>
#       <td id="T_5beae_row2_col4" class="data row2 col4" >0.9711</td>
#       <td id="T_5beae_row2_col5" class="data row2 col5" >0.0773</td>
#       <td id="T_5beae_row2_col6" class="data row2 col6" >0.0567</td>
#       <td id="T_5beae_row2_col7" class="data row2 col7" >0.8140</td>
#     </tr>
#     <tr>
#       <th id="T_5beae_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_5beae_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_5beae_row3_col1" class="data row3 col1" >919.8439</td>
#       <td id="T_5beae_row3_col2" class="data row3 col2" >3757700.7801</td>
#       <td id="T_5beae_row3_col3" class="data row3 col3" >1899.5914</td>
#       <td id="T_5beae_row3_col4" class="data row3 col4" >0.9634</td>
#       <td id="T_5beae_row3_col5" class="data row3 col5" >0.1024</td>
#       <td id="T_5beae_row3_col6" class="data row3 col6" >0.0770</td>
#       <td id="T_5beae_row3_col7" class="data row3 col7" >0.5320</td>
#     </tr>
#     <tr>
#       <th id="T_5beae_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_5beae_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_5beae_row4_col1" class="data row4 col1" >1011.9136</td>
#       <td id="T_5beae_row4_col2" class="data row4 col2" >5382439.9624</td>
#       <td id="T_5beae_row4_col3" class="data row4 col3" >2244.3755</td>
#       <td id="T_5beae_row4_col4" class="data row4 col4" >0.9465</td>
#       <td id="T_5beae_row4_col5" class="data row4 col5" >0.1082</td>
#       <td id="T_5beae_row4_col6" class="data row4 col6" >0.0779</td>
#       <td id="T_5beae_row4_col7" class="data row4 col7" >0.4590</td>
#     </tr>
#     <tr>
#       <th id="T_5beae_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_5beae_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_5beae_row5_col1" class="data row5 col1" >2413.5698</td>
#       <td id="T_5beae_row5_col2" class="data row5 col2" >14120482.9350</td>
#       <td id="T_5beae_row5_col3" class="data row5 col3" >3726.1631</td>
#       <td id="T_5beae_row5_col4" class="data row5 col4" >0.8621</td>
#       <td id="T_5beae_row5_col5" class="data row5 col5" >0.6689</td>
#       <td id="T_5beae_row5_col6" class="data row5 col6" >0.2875</td>
#       <td id="T_5beae_row5_col7" class="data row5
# Processing:   0%|          | 0/73 [00:00<?, ?it/s]
